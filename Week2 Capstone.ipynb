# %% [markdown]
# ![106352169-15798088460535_spaceneedleontheseattleskyline-lookingsouthwithmt.rainierinthebackground-courtesyspaceneedlellc.jpg](attachment:106352169-15798088460535_spaceneedleontheseattleskyline-lookingsouthwithmt.rainierinthebackground-courtesyspaceneedlellc.jpg)

# %% [markdown]
# <h1>INTRODUCTION</h1>

# %% [markdown]
# Seattle is a rapidly growing metropolis nested in the heart of Puget Sound. Characteristic of most large cities, Seattle's building and transit infrastructure has struggled to keep pace with the city's unprecendented international appeal. On a typical Monday morning, droves of automobiles saturate I-5 and other major highways. Bumper-to-bumper traffic leaves early commuters with their feet perpetually on the brakes, occassionally passing by unfortunate victims of car collisions along shoulders of the road. While the frequent collisions are a source of inconvenience to those traversing Seattle streets, these collisions are also a growing concern for legal and medical professionals. These groups must assess the number of preventable human fatalities, the economic impact of traffic delays, the dollar value of property damage, and the strain imposed on emergency care resources.

# %% [markdown]
# <h1>MOTTO OF PROJECT

# %% [markdown]
# The purpose of the this model is to predict car accident severity using best-practice machine learning techniques.
#
# As previously stated, the target audiences are:
#
# Seattle Lawmakers: Provides lawmakers with data that can directly influence policy (ex. speed limits, tolling regulations, stop signs, DUI checkpoints)
# Insurance Companies: Provides insurance companies with cross-sectional probabilities of damage that directly impact inusrance premiums.
# Medical Providers: Provides medical providers a proactive model for staffing, medical supply procurement, and triage care.

# %% [markdown]
# <h1>DETAILS ON DATA</h1>
# Data Owner: Seattle of Seattle, SDOT Traffic Management Division
# Dates: Min: 02/15/2006; Max: 05/20/2020
# Features in Dataset: 37
# Dependent Variable: SEVERITYCODE

# %% [markdown]
# "Raw Data can be viewed <a href=\"https://s3.us.cloud-object-storage.appdomain.cloud/cf-courses-data/CognitiveClass/DP0701EN/version-2/Data-Collisions.csv\">here.</a><br>\n",
#     "Metadata can be viewed <a href=\"https://s3.us.cloud-object-storage.appdomain.cloud/cf-courses-data/CognitiveClass/DP0701EN/version-2/Metadata.pdf\">here.</a>\n",
#     "\n"

# %%
#Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import json

# %%
#READ RAW DATA
collision_data = pd.read_csv('https://s3.us.cloud-object-storage.appdomain.cloud/cf-courses-data/CognitiveClass/DP0701EN/version-2/Data-Collisions.csv')
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (33) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#Reduce Raw Data to Relevant Features
featureframe = pd.DataFrame(collision_data,columns=['ADDRTYPE','PERSONCOUNT','PEDCOUNT','PEDCYLCOUNT','VEHCOUNT','INATTENTIONIND', 'WEATHER', 'ROADCOND', 'LIGHTCOND', 'PEDROWNOTGRNT', 'SPEEDING', 'ST_COLCODE', 'HITPARKEDCAR', 'INCDTTM'])
featureframe
# Out:
#             ADDRTYPE  PERSONCOUNT  PEDCOUNT  PEDCYLCOUNT  VEHCOUNT  \
# 0       Intersection            2         0            0         2
# 1              Block            2         0            0         2
# 2              Block            4         0            0         3
# 3              Block            3         0            0         3
# 4       Intersection            2         0            0         2
# 5       Intersection            2         0            0         2
# 6       Intersection            2         0            0         2
# 7       Intersection            3         0            1         1
# 8              Block            2         0            0         2
# 9       Intersection            2         0            0         2
# 10             Alley            2         0            0         2
# 11      Intersection            2         0            0         2
# 12             Block            0         0            0         2
# 13             Block            2         0            0         2
# 14             Block            2         0            0         2
# 15             Block            1         0            0         0
# 16      Intersection            3         0            0         2
# 17             Block            0         0            0         2
# 18             Block            4         0            0         3
# 19             Block            2         0            0         2
# 20             Block            3         0            0         2
# 21      Intersection            5         0            0         3
# 22             Block            2         0            0         2
# 23             Block            1         0            0         1
# 24      Intersection            3         0            0         2
# 25             Block            2         0            1         1
# 26      Intersection            2         0            0         2
# 27             Block            2         0            0         2
# 28             Block            2         0            0         2
# 29             Block            2         0            0         2
# ...              ...          ...       ...          ...       ...
# 194643         Block            2         0            0         2
# 194644  Intersection            2         0            0         2
# 194645  Intersection            5         0            0         2
# 194646         Block            2         0            0         0
# 194647         Block            2         1            0         1
# 194648         Block            2         0            0         2
# 194649  Intersection            6         0            0         3
# 194650         Block            5         0            0         5
# 194651  Intersection            3         1            0         1
# 194652         Block            3         0            0         2
# 194653         Block            6         0            0         6
# 194654  Intersection            2         0            0         0
# 194655  Intersection            4         0            0         0
# 194656  Intersection            2         1            0         1
# 194657         Block            2         0            0         2
# 194658         Block            3         0            0         3
# 194659         Block            2         0            0         2
# 194660         Block            1         0            0         1
# 194661         Block            2         0            0         2
# 194662         Block            2         0            0         2
# 194663         Block            3         0            0         2
# 194664  Intersection            8         0            0         3
# 194665  Intersection            2         0            0         2
# 194666         Block            2         0            0         2
# 194667         Block            1         0            0         1
# 194668         Block            3         0            0         2
# 194669         Block            2         0            0         2
# 194670  Intersection            3         0            0         2
# 194671  Intersection            2         0            1         1
# 194672         Block            2         0            0         2
#
#        INATTENTIONIND   WEATHER ROADCOND                LIGHTCOND  \
# 0                 NaN  Overcast      Wet                 Daylight
# 1                 NaN   Raining      Wet  Dark - Street Lights On
# 2                 NaN  Overcast      Dry                 Daylight
# 3                 NaN     Clear      Dry                 Daylight
# 4                 NaN   Raining      Wet                 Daylight
# 5                 NaN     Clear      Dry                 Daylight
# 6                 NaN   Raining      Wet                 Daylight
# 7                 NaN     Clear      Dry                 Daylight
# 8                 NaN     Clear      Dry                 Daylight
# 9                 NaN     Clear      Dry                 Daylight
# 10                NaN  Overcast      Dry                 Daylight
# 11                NaN     Clear      Dry                 Daylight
# 12                NaN   Raining      Wet  Dark - Street Lights On
# 13                NaN   Raining      Wet  Dark - No Street Lights
# 14                NaN     Clear      Dry  Dark - Street Lights On
# 15                NaN       NaN      NaN                      NaN
# 16                NaN  Overcast      Dry                 Daylight
# 17                NaN  Overcast      Dry                 Daylight
# 18                NaN     Clear      Dry                 Daylight
# 19                NaN   Unknown      Dry                  Unknown
# 20                NaN     Clear      Dry  Dark - Street Lights On
# 21                NaN     Clear      Dry                 Daylight
# 22                  Y     Clear      Dry  Dark - Street Lights On
# 23                NaN   Unknown  Unknown                  Unknown
# 24                NaN     Clear      Dry                 Daylight
# 25                  Y     Clear      Dry                 Daylight
# 26                NaN  Overcast      Wet                  Unknown
# 27                NaN     Clear      Dry                 Daylight
# 28                NaN     Clear      Dry                 Daylight
# 29                NaN     Clear      Dry                 Daylight
# ...               ...       ...      ...                      ...
# 194643            NaN     Clear      Dry  Dark - Street Lights On
# 194644            NaN     Clear      Dry                     Dusk
# 194645            NaN     Clear      Dry  Dark - Street Lights On
# 194646            NaN       NaN      NaN                      NaN
# 194647              Y   Raining      Wet                     Dusk
# 194648            NaN   Raining      Wet  Dark - Street Lights On
# 194649            NaN     Clear      Dry  Dark - Street Lights On
# 194650            NaN     Clear      Dry                 Daylight
# 194651            NaN     Clear      Wet  Dark - Street Lights On
# 194652              Y  Overcast      Wet                     Dusk
# 194653            NaN  Overcast      Wet  Dark - Street Lights On
# 194654            NaN       NaN      NaN                      NaN
# 194655            NaN       NaN      NaN                      NaN
# 194656            NaN     Clear      Dry                 Daylight
# 194657            NaN   Raining      Wet  Dark - Street Lights On
# 194658            NaN   Raining      Wet  Dark - Street Lights On
# 194659            NaN   Raining      Wet  Dark - Street Lights On
# 194660            NaN   Raining      Wet                    Other
# 194661            NaN     Clear      Dry                 Daylight
# 194662            NaN     Clear      Dry                     Dusk
# 194663              Y   Raining      Wet                 Daylight
# 194664            NaN     Clear      Dry                 Daylight
# 194665            NaN     Clear      Dry                 Daylight
# 194666            NaN     Clear      Wet                 Daylight
# 194667            NaN   Raining      Wet  Dark - Street Lights On
# 194668            NaN     Clear      Dry                 Daylight
# 194669              Y   Raining      Wet                 Daylight
# 194670            NaN     Clear      Dry                 Daylight
# 194671            NaN     Clear      Dry                     Dusk
# 194672            NaN     Clear      Wet                 Daylight
#
#        PEDROWNOTGRNT SPEEDING ST_COLCODE HITPARKEDCAR                 INCDTTM
# 0                NaN      NaN         10            N    3/27/2013 2:54:00 PM
# 1                NaN      NaN         11            N   12/20/2006 6:55:00 PM
# 2                NaN      NaN         32            N  11/18/2004 10:20:00 AM
# 3                NaN      NaN         23            N    3/29/2013 9:26:00 AM
# 4                NaN      NaN         10            N    1/28/2004 8:04:00 AM
# 5                NaN      NaN         10            N    4/20/2019 5:42:00 PM
# 6                NaN      NaN         10            N               12/9/2008
# 7                NaN      NaN          5            N    4/15/2020 5:47:00 PM
# 8                NaN      NaN         32            N    6/15/2006 1:00:00 PM
# 9                NaN      NaN         10            N    3/20/2006 3:49:00 PM
# 10               NaN      NaN         22            N    5/25/2006 6:20:00 PM
# 11               NaN      NaN         10            N    8/11/2005 5:30:00 PM
# 12               NaN      NaN         14            N   5/17/2006 12:51:00 PM
# 13               NaN      NaN         32            N   12/22/2005 5:13:00 PM
# 14               NaN      NaN         30            N    3/31/2013 2:09:00 AM
# 15               NaN      NaN                       N               4/20/2020
# 16               NaN      NaN         28            N                7/1/2005
# 17               NaN      NaN         14            N    1/16/2004 8:25:00 AM
# 18               NaN      NaN         14            N    4/17/2020 2:44:00 PM
# 19               NaN      NaN         32            N                6/1/2009
# 20               NaN      NaN         14            N    3/27/2013 8:45:00 PM
# 21               NaN      NaN         10            N    3/28/2013 4:22:00 PM
# 22               NaN      NaN         32            N   7/18/2008 10:02:00 PM
# 23               NaN      NaN         51            N    9/12/2004 6:20:00 AM
# 24               NaN        Y         14            N   3/31/2013 10:05:00 AM
# 25               NaN      NaN          5            N    4/25/2019 9:40:00 AM
# 26               NaN      NaN         28            N   11/13/2010 3:24:00 PM
# 27               NaN      NaN         10            N    7/23/2007 4:30:00 PM
# 28               NaN      NaN         23            N    3/25/2013 2:42:00 PM
# 29               NaN      NaN         32            N  11/16/2006 11:00:00 AM
# ...              ...      ...        ...          ...                     ...
# 194643           NaN      NaN         20            N  11/17/2018 11:06:00 PM
# 194644           NaN      NaN         10            N    1/17/2019 5:11:00 PM
# 194645           NaN      NaN         16            N   10/20/2018 2:07:00 AM
# 194646           NaN      NaN                       N              12/13/2018
# 194647           NaN      NaN          0            N    12/9/2018 6:15:00 PM
# 194648           NaN      NaN         10            N   11/30/2018 6:42:00 PM
# 194649           NaN      NaN         28            N    12/2/2018 6:54:00 PM
# 194650           NaN      NaN         32            Y    1/13/2019 8:36:00 AM
# 194651           NaN      NaN          0            N   12/23/2018 9:45:00 PM
# 194652           NaN      NaN         32            Y   12/20/2018 4:21:00 PM
# 194653           NaN      NaN         32            Y  12/10/2018 12:47:00 AM
# 194654           NaN      NaN                       N               1/10/2019
# 194655           NaN      NaN                       N               1/20/2019
# 194656           NaN      NaN          2            N   1/23/2019 10:15:00 AM
# 194657           NaN      NaN         11            N   11/26/2018 3:37:00 AM
# 194658           NaN      NaN         14            N    1/18/2019 9:57:00 PM
# 194659           NaN      NaN         32            Y   11/27/2018 5:30:00 PM
# 194660           NaN      NaN         52            N  12/23/2018 12:52:00 PM
# 194661           NaN      NaN         29            N    3/22/2019 5:19:00 PM
# 194662           NaN      NaN         32            Y    12/5/2018 5:09:00 PM
# 194663           NaN      NaN         10            N    1/9/2019 12:51:00 PM
# 194664           NaN      NaN         10            N   12/30/2018 3:25:00 PM
# 194665           NaN      NaN         10            N    12/5/2018 1:00:00 PM
# 194666           NaN      NaN         10            N     1/4/2019 1:46:00 PM
# 194667           NaN      NaN         50            N   11/28/2018 9:34:00 PM
# 194668           NaN      NaN         24            N   11/12/2018 8:12:00 AM
# 194669           NaN      NaN         13            N   12/18/2018 9:14:00 AM
# 194670           NaN      NaN         28            N    1/19/2019 9:25:00 AM
# 194671           NaN      NaN          5            N    1/15/2019 4:48:00 PM
# 194672           NaN      NaN         14            N   11/30/2018 3:45:00 PM
#
# [194673 rows x 14 columns]
